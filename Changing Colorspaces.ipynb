# %%
#Bai toan 1
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.imshow(img,interpolation= 'bicubic')
plt.title('Original BGR')
# Out:
# Text(0.5, 1.0, 'Original BGR')

# %%
#Bai toan 2
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)
# BGR->RGB
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.imshow(img,interpolation= 'bicubic')
plt.title('Original RGB')
# Out:
# Text(0.5, 1.0, 'Original RGB')

# %%
#Bai toan 3
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)

img1 = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img2 = cv2.cvtColor(img1,cv2.COLOR_GRAY2BGR)

plt.figure(figsize=(12,12))
#SHOW img
plt.subplot(1,3,1),plt.imshow(img)
plt.title('Image BGR')
#SHOW img1
plt.subplot(1,3,2),plt.imshow(img1,cmap='gray')
plt.title('Image BGR->GRAY')
#SHOW img2
plt.subplot(1,3,3),plt.imshow(img2)
plt.title('Image GRAY->BGR')
# Out:
# Text(0.5, 1.0, 'Image GRAY->BGR')

# %%
#Bai toan 4
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img1,cv2.COLOR_RGB2GRAY)

plt.figure(figsize=(12,12))
#SHOW img
plt.subplot(1,3,1),plt.imshow(img)
plt.title('Image BGR')
#SHOW img1
plt.subplot(1,3,2),plt.imshow(img1,cmap='gray')
plt.title('Image BGR->RGB')
#SHOW img2
plt.subplot(1,3,3),plt.imshow(img2,cmap='gray')
plt.title('Image RGB->GRAY')
# Out:
# Text(0.5, 1.0, 'Image RGB->GRAY')

# %%
#Bai toan 5
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)

img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img1,cv2.COLOR_RGB2HSV)
img3 = cv2.cvtColor(img2,cv2.COLOR_HSV2BGR)

plt.figure(figsize=(12,12))
#SHOW img1
plt.subplot(1,3,1),plt.imshow(img1)
plt.title('Image RGB')
#SHOW img2
plt.subplot(1,3,2),plt.imshow(img2,cmap='gray')
plt.title('Image RGB->HSV')
#SHOW img3
plt.subplot(1,3,3),plt.imshow(img3,cmap='gray')
plt.title('Image HSV->BGR')
# Out:
# Text(0.5, 1.0, 'Image HSV->BGR')

# %%
#Bai toan 6
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread('/content/drive/MyDrive/00. Dataset Image Processing/statue.png',1)

img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img1,cv2.COLOR_RGB2HSV)
img3 = cv2.cvtColor(img2,cv2.COLOR_HSV2RGB)

plt.figure(figsize=(12,12))
#SHOW img1
plt.subplot(1,3,1),plt.imshow(img1)
plt.title('Image RGB')
#SHOW img2
plt.subplot(1,3,2),plt.imshow(img2,cmap='gray')
plt.title('Image RGB->HSV')
#SHOW img3
plt.subplot(1,3,3),plt.imshow(img3,cmap='gray')
plt.title('Image HSV->RGB')
# Out:
# Text(0.5, 1.0, 'Image HSV->RGB')
