# %%
begin
  large_image = load('/content/drive/MyDrive/00. Dataset Image Processing/cropped_building.png') 
  image = shrink_image(large_image, 7)
end
size(image)
# Out:
#   File "<ipython-input-2-988dd4c1f9ae>", line 2
#     large_image = load('/content/drive/MyDrive/00. Dataset Image Processing/cropped_building.png')
#     ^
# IndentationError: unexpected indent
